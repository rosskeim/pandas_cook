# %%
import pandas as pd

# %%
import numpy as np

# %%
fueleco = pd.read_csv("vehicles.csv.zip")

# %%
fueleco
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 39096  14.982273         0.0        0.0        0.0      19      0.0        0
# 39097  14.330870         0.0        0.0        0.0      20      0.0        0
# 39098  15.695714         0.0        0.0        0.0      18      0.0        0
# 39099  15.695714         0.0        0.0        0.0      18      0.0        0
# 39100  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
fueleco.mean()
# Out:
# barrels08             17.442712
# barrelsA08             0.219276
# charge120              0.000000
# charge240              0.029630
# city08                18.077799
# city08U                5.040648
# cityA08                0.569883
# cityA08U               0.416097
# cityCD                 0.000560
# cityE                  0.225181
# cityUF                 0.000975
# co2                   72.538989
# co2A                   5.543950
# co2TailpipeAGpm       17.826864
# co2TailpipeGpm       470.704841
# comb08                20.323828
# comb08U                5.652724
# combA08                0.631160
# combA08U               0.453725
# combE                  0.230912
# combinedCD             0.000459
# combinedUF             0.000959
# cylinders              5.729105
# displ                  3.309829
# engId               8582.377382
# feScore                0.122580
# fuelCost08          2242.470781
# fuelCostA08           91.335260
# ghgScore               0.120866
# ...

# %%
fueleco.std()
# Out:
# barrels08              4.580230
# barrelsA08             1.143837
# charge120              0.000000
# charge240              0.487408
# city08                 6.970672
# city08U               10.462790
# cityA08                4.297124
# cityA08U               4.093495
# cityCD                 0.045392
# cityE                  3.180894
# cityUF                 0.022785
# co2                  163.252019
# co2A                  55.956932
# co2TailpipeAGpm       93.937414
# co2TailpipeGpm       122.351021
# comb08                 6.882807
# comb08U               11.231748
# combA08                4.395797
# combA08U               4.131767
# combE                  3.244463
# combinedCD             0.040759
# combinedUF             0.022392
# cylinders              1.754487
# displ                  1.361925
# engId              17606.675590
# feScore                2.516348
# fuelCost08           601.273869
# fuelCostA08          479.485802
# ghgScore               2.512612
# ...

# %%
fueleco.quantile(
    [0, 0.25, 0.5, 0.75, 1]
)
# Out:
#       barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0.00   0.060000    0.000000        0.0        0.0     6.0      0.0      0.0
# 0.25  14.330870    0.000000        0.0        0.0    15.0      0.0      0.0
# 0.50  17.347895    0.000000        0.0        0.0    17.0      0.0      0.0
# 0.75  20.115000    0.000000        0.0        0.0    20.0      0.0      0.0
# 1.00  47.087143   18.311667        0.0       12.0   150.0    150.0    145.0
#
#       cityA08U  cityCD  cityE  ...     UCity    UCityA  UHighway  UHighwayA  \
# 0.00    0.0000    0.00    0.0  ...    0.0000    0.0000    0.0000     0.0000
# 0.25    0.0000    0.00    0.0  ...   18.0000    0.0000   27.3704     0.0000
# 0.50    0.0000    0.00    0.0  ...   21.1111    0.0000   33.0000     0.0000
# 0.75    0.0000    0.00    0.0  ...   25.4756    0.0000   38.6000     0.0000
# 1.00  145.0835    5.35  122.0  ...  224.8000  207.2622  182.7000   173.1436
#
# ...

# %%
fueleco.describe()
# Out:
#           barrels08    barrelsA08  charge120     charge240        city08  \
# count  39101.000000  39101.000000    39101.0  39101.000000  39101.000000
# mean      17.442712      0.219276        0.0      0.029630     18.077799
# std        4.580230      1.143837        0.0      0.487408      6.970672
# min        0.060000      0.000000        0.0      0.000000      6.000000
# 25%       14.330870      0.000000        0.0      0.000000     15.000000
# 50%       17.347895      0.000000        0.0      0.000000     17.000000
# 75%       20.115000      0.000000        0.0      0.000000     20.000000
# max       47.087143     18.311667        0.0     12.000000    150.000000
#
#             city08U       cityA08      cityA08U        cityCD         cityE  \
# count  39101.000000  39101.000000  39101.000000  39101.000000  39101.000000
# mean       5.040648      0.569883      0.416097      0.000560      0.225181
# std       10.462790      4.297124      4.093495      0.045392      3.180894
# ...
